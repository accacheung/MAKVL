# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Total WA sales by calendar year
revenue = "2014_to_2016_WA_revenue.csv"

revenue_df = fy2015_df = pd.read_csv(revenue)

# %%
revenue_df.tail()
# Out:
#            Date       Sales  Excise Tax Due  Sales (Shelf Price)
# 940  12/27/2016  3324831.99       752106.45           4076938.44
# 941  12/28/2016  3452036.10       797870.30           4249906.40
# 942  12/29/2016  4200475.36       859655.24           5060130.60
# 943  12/30/2016  5221889.13      1243811.86           6465700.99
# 944  12/31/2016  3713397.08      1354076.00           5067473.08

# %%
#Retail revenue broken down by FY and county
fy2015_retail_revenue = "fy2015_WA_retail_revenue_by_county.csv"
fy2016_retail_revenue = "fy2016_WA_retail_revenue_by_county.csv"
fy2017_retail_revenue = "fy2017_WA_retail_revenue_by_county.csv"

fy2015_df = pd.read_csv(fy2015_retail_revenue)
fy2016_df = pd.read_csv(fy2016_retail_revenue)
fy2017_df = pd.read_csv(fy2017_retail_revenue)

# %%
fy2016_df
# Out:
#           County         Reporting Period     Total Sales      Excise Tax
# 0         ASOTIN  07/01/2015 - 06/30/2016     $2,390,504        $884,487
# 1         BENTON  07/01/2015 - 06/30/2016     $4,970,194      $1,838,972
# 2         CHELAN  07/01/2015 - 06/30/2016     $4,801,762      $1,776,652
# 3        CLALLAM  07/01/2015 - 06/30/2016     $5,217,200      $1,930,364
# 4          CLARK  07/01/2015 - 06/30/2016    $46,119,692     $17,064,286
# 5        COWLITZ  07/01/2015 - 06/30/2016     $9,996,138      $3,698,571
# 6        DOUGLAS  07/01/2015 - 06/30/2016     $1,697,135        $627,940
# 7          FERRY  07/01/2015 - 06/30/2016       $417,800        $154,586
# 8       FRANKLIN  07/01/2015 - 06/30/2016       $123,213         $45,589
# 9          GRANT  07/01/2015 - 06/30/2016     $3,715,477      $1,374,727
# 10  GRAYS HARBOR  07/01/2015 - 06/30/2016     $6,323,625      $2,339,741
# 11        ISLAND  07/01/2015 - 06/30/2016     $5,730,021      $2,120,108
# ...

# %%
cleanedfy2016=df = fy2016_df.dropna(how='any')
cleanedfy2016
# Out:
#           County         Reporting Period     Total Sales     Excise Tax
# 0         ASOTIN  07/01/2015 - 06/30/2016     $2,390,504       $884,487
# 1         BENTON  07/01/2015 - 06/30/2016     $4,970,194     $1,838,972
# 2         CHELAN  07/01/2015 - 06/30/2016     $4,801,762     $1,776,652
# 3        CLALLAM  07/01/2015 - 06/30/2016     $5,217,200     $1,930,364
# 4          CLARK  07/01/2015 - 06/30/2016    $46,119,692    $17,064,286
# 5        COWLITZ  07/01/2015 - 06/30/2016     $9,996,138     $3,698,571
# 6        DOUGLAS  07/01/2015 - 06/30/2016     $1,697,135       $627,940
# 7          FERRY  07/01/2015 - 06/30/2016       $417,800       $154,586
# 8       FRANKLIN  07/01/2015 - 06/30/2016       $123,213        $45,589
# 9          GRANT  07/01/2015 - 06/30/2016     $3,715,477     $1,374,727
# 10  GRAYS HARBOR  07/01/2015 - 06/30/2016     $6,323,625     $2,339,741
# 11        ISLAND  07/01/2015 - 06/30/2016     $5,730,021     $2,120,108
# ...

# %%
cleanedfy2016.to_csv('cleaned_fy2016_WA_retail_revenue_by_county.csv')

# %%
cleanedfy2017=df = fy2017_df.dropna(how='any')
cleanedfy2017
# Out:
#           County         Reporting Period        Total Sales        Excise Tax
# 0          ADAMS  07/01/2016 - 06/30/2017     $1,092,330.91       $404,162.42
# 1         ASOTIN  07/01/2016 - 06/30/2017     $7,901,349.03     $2,923,499.13
# 2         BENTON  07/01/2016 - 06/30/2017    $14,867,438.10     $5,500,952.10
# 3         CHELAN  07/01/2016 - 06/30/2017     $7,449,552.84     $2,756,334.63
# 4        CLALLAM  07/01/2016 - 06/30/2017    $10,671,708.82     $3,948,532.28
# 5          CLARK  07/01/2016 - 06/30/2017    $56,832,141.35    $21,027,892.30
# 6        COWLITZ  07/01/2016 - 06/30/2017    $14,851,660.48     $5,495,114.38
# 7        DOUGLAS  07/01/2016 - 06/30/2017     $2,522,689.32       $933,395.05
# 8          FERRY  07/01/2016 - 06/30/2017       $746,938.22       $276,367.14
# 9          GRANT  07/01/2016 - 06/30/2017     $7,815,680.27     $2,891,801.72
# 10  GRAYS HARBOR  07/01/2016 - 06/30/2017    $11,364,874.91     $4,205,003.72
# ...

# %%
cleanedfy2017.to_csv('cleaned_fy2017_WA_retail_revenue_by_county.csv')

# %%
#Total WA sales by month, 2015 to 2017
monthly_revenue = "monthly sales data.csv"

monthly_revenue_df = fy2015_df = pd.read_csv(monthly_revenue)

monthly_revenue_df.head()
# Out:
#        Month            2015            2016             2017             2018
# 0       July   $3,237,212.69  $47,599,853.95   $98,527,349.87  $126,886,202.43
# 1     August   $7,053,729.98  $53,497,874.05  $110,196,458.47  $133,585,566.87
# 2  September   $8,627,392.04  $59,554,904.30  $114,339,124.48  $131,546,944.47
# 3    October  $13,051,504.96  $61,257,765.37  $115,235,047.13  $136,163,972.46
# 4   November  $16,082,629.52  $57,444,221.59  $111,839,681.45              NaN
